# %% [markdown]
# # Polarized Electric Fields
#
# **Scott Prahl**
#
# *March 2020*
#
# This module shows that the basic idea in polarized light is that there is a fixed phase relationship between the electric fields in the horizontal and vertical directions.
#
# Details of the assumptions are given in the [Jupyter notebook on Conventions](00-Jones-Conventions.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

import pypolar.jones as jones
import pypolar.visualization as vis

# %% [markdown]
# ## 2D represention of a 3D vector fields
#
# Light is propagating in the z-direction.  The graphs below are x-y cross sections.  The horizontal axis corresponds to the $E_x$ field and the vertical axis is the $E_y$ field. The graphs can thought of as time exposures:  the blue line shows all values that the polarization field can have.

# %%
theta = 0
v = jones.field_linear(np.radians(theta))
print("Jones vector for %d° linearly polarized light (horizontal)" % theta)
vis.draw_jones_animated(v,nframes=32)
# Out:
# Jones vector for 0° linearly polarized light (horizontal)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1ec03b54dbd04b92aa325b7506020f86">
#   <div class="anim-controls">
#     <input id="_anim_slider1ec03b54dbd04b92aa325b7506020f86" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1ec03b54dbd04b92aa325b7506020f86.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim1ec03b54dbd04b92aa325b7506020f86.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select1ec03b54dbd04b92aa325b7506020f86" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1ec03b54dbd04b92aa325b7506020f86"
#              >
#       <label for="_anim_radio1_1ec03b54dbd04b92aa325b7506020f86">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1ec03b54dbd04b92aa325b7506020f86"
#              checked>
#       <label for="_anim_radio2_1ec03b54dbd04b92aa325b7506020f86">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1ec03b54dbd04b92aa325b7506020f86"
#              >
#       <label for="_anim_radio3_1ec03b54dbd04b92aa325b7506020f86">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1ec03b54dbd04b92aa325b7506020f86";
#     var slider_id = "_anim_slider1ec03b54dbd04b92aa325b7506020f86";
#     var loop_select_id = "_anim_loop_select1ec03b54dbd04b92aa325b7506020f86";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nO3dd1jVdf/H8dcBhAOCijJygnuguDVX\
# DjJXpjkqM811a92VWpat2zLXr2xaplaa27DMzNxm5ShUxC1qDjC3EiooMg7n8/vDuqelJnAOfJ+P\
# 6+JS4Zzv930uLo5PvtNmjDECAACwEA9XDwAAAJDXCCAAAGA5BBAAALAcAggAAFgOAQQAACyHAAIA\
# AJZDAAEAAMshgAAAgOUQQAAAwHIIIAAAYDkEEAAAsBwCCAAAWA4BBAAALIcAAgAAlkMAAQAAyyGA\
# AACA5RBAAADAcgggAABgOQQQAACwHAIIAABYDgEEAAAshwACAACWQwABAADLIYAAAIDlEEAAAMBy\
# CCAAAGA5BBAAALAcAggAAFgOAQQAACyHAAIAAJZDAAEAAMshgAAAgOUQQAAAwHIIIAAAYDkEEAAA\
# sBwCCAAAWA4BBAAALIcAAgAAlk

# %%
theta = 90
v = jones.field_linear(np.radians(theta))
print("Jones vector for %d° linearly polarized light (vertical)" % theta)
vis.draw_jones_animated(v,nframes=32)
# Out:
# Jones vector for 90° linearly polarized light (vertical)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgeead76a2101241b08b8664da476a1ba5">
#   <div class="anim-controls">
#     <input id="_anim_slidereead76a2101241b08b8664da476a1ba5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animeead76a2101241b08b8664da476a1ba5.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animeead76a2101241b08b8664da476a1ba5.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecteead76a2101241b08b8664da476a1ba5" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_eead76a2101241b08b8664da476a1ba5"
#              >
#       <label for="_anim_radio1_eead76a2101241b08b8664da476a1ba5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_eead76a2101241b08b8664da476a1ba5"
#              checked>
#       <label for="_anim_radio2_eead76a2101241b08b8664da476a1ba5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_eead76a2101241b08b8664da476a1ba5"
#              >
#       <label for="_anim_radio3_eead76a2101241b08b8664da476a1ba5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgeead76a2101241b08b8664da476a1ba5";
#     var slider_id = "_anim_slidereead76a2101241b08b8664da476a1ba5";
#     var loop_select_id = "_anim_loop_selecteead76a2101241b08b8664da476a1ba5";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nO3dd3hUdf638Xsmk2SSkJBACFIThNCC\
# 1AQIvQkIgrJWQBFEEX+iguyqCyIqguuuDUEXERawIQqooBSRKj0JvdeAFGkBEiB15jx/BNtDS5nJ\
# TDjv13XlEmbO+Z7PXBZuZ86cYzEMw0BERETERKyeHkBERESkqCmARERExHQUQCIiImI6CiAREREx\
# HQWQiIiImI4CSERERExHASQiIiKmowASERER01EAiYiIiOkogERERMR0FEAiIiJiOgogERERMR0F\
# kIiIiJiOAkhERERMRwEkIiIipqMAEhEREdNRAImIiIjpKIBERETEdBRAIiIiYjoKIBERETEdBZCI\
# iIiYjgJIRERETEcBJCIiIqajABIRERHTUQCJiIiI6SiARERExHQUQCIiImI6CiARERExHQWQiIiI\
# mI4CSERERExHASQiIiKmowASER

# %%
theta = 45
v = jones.field_linear(np.radians(theta))
print("Jones vector for %d° linearly polarized light" % theta)
vis.draw_jones_animated(v,nframes=32)
# Out:
# Jones vector for 45° linearly polarized light
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img55b45ed7edab4703aba9d93f18894a18">
#   <div class="anim-controls">
#     <input id="_anim_slider55b45ed7edab4703aba9d93f18894a18" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim55b45ed7edab4703aba9d93f18894a18.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim55b45ed7edab4703aba9d93f18894a18.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select55b45ed7edab4703aba9d93f18894a18" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_55b45ed7edab4703aba9d93f18894a18"
#              >
#       <label for="_anim_radio1_55b45ed7edab4703aba9d93f18894a18">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_55b45ed7edab4703aba9d93f18894a18"
#              checked>
#       <label for="_anim_radio2_55b45ed7edab4703aba9d93f18894a18">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_55b45ed7edab4703aba9d93f18894a18"
#              >
#       <label for="_anim_radio3_55b45ed7edab4703aba9d93f18894a18">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img55b45ed7edab4703aba9d93f18894a18";
#     var slider_id = "_anim_slider55b45ed7edab4703aba9d93f18894a18";
#     var loop_select_id = "_anim_loop_select55b45ed7edab4703aba9d93f18894a18";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nO3dd3iTZdsG8LO7jDLK3nvvvQRki4CC\
# ykZEQHwFRZbsDaIIKPABgqIMy16yoewhq+xVNmVTShkddCW5vz8uGrrSpm3apH3O33FwVDKe3Gnf\
# tzm5x3XZKaUUiIiIiDTE3toDICIiIkptDEBERESkOQxAREREpDkMQERERKQ5DEBERESkOQxARERE\
# pDkMQERERKQ5DEBERESkOQxAREREpDkMQERERKQ5DEBERESkOQxAREREpDkMQERERKQ5DEBERESk\
# OQxAREREpDkMQERERKQ5DEBERESkOQxAREREpDkMQERERKQ5DEBERESkOQxAREREpDkMQERERKQ5\
# DEBERESkOQxAREREpDkMQERERKQ5DEBERESkOQxAREREpDkMQERERKQ5DEBERESkOQxAREREpDkM\
# QERERKQ5DEBERESkOQxAREREpD

# %%
v = jones.field_right_circular()
print("Jones vector for right circularly polarized light")
vis.draw_jones_animated(v,nframes=32)
# Out:
# Jones vector for right circularly polarized light
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5a7b1135da5d4f5fabee7495045d0c27">
#   <div class="anim-controls">
#     <input id="_anim_slider5a7b1135da5d4f5fabee7495045d0c27" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5a7b1135da5d4f5fabee7495045d0c27.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim5a7b1135da5d4f5fabee7495045d0c27.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select5a7b1135da5d4f5fabee7495045d0c27" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5a7b1135da5d4f5fabee7495045d0c27"
#              >
#       <label for="_anim_radio1_5a7b1135da5d4f5fabee7495045d0c27">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5a7b1135da5d4f5fabee7495045d0c27"
#              checked>
#       <label for="_anim_radio2_5a7b1135da5d4f5fabee7495045d0c27">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5a7b1135da5d4f5fabee7495045d0c27"
#              >
#       <label for="_anim_radio3_5a7b1135da5d4f5fabee7495045d0c27">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5a7b1135da5d4f5fabee7495045d0c27";
#     var slider_id = "_anim_slider5a7b1135da5d4f5fabee7495045d0c27";
#     var loop_select_id = "_anim_loop_select5a7b1135da5d4f5fabee7495045d0c27";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nOzdd1zV5RfA8c+FyxREBTcq7j0BSzN3\
# uTJHbtRSy9UvNbXcOSotTUtzZZkjd2paWo7cW9wLzb0nCgiy7/P741HSFGVcuBfveb9evpB7v/f5\
# nosFh2ecY1BKKYQQQgghbIidpQMQQgghhEhvkgAJIYQQwuZIAiSEEEIImyMJkBBCCCFsjiRAQggh\
# hLA5kgAJIYQQwuZIAiSEEEIImyMJkBBCCCFsjiRAQgghhLA5kgAJIYQQwuZIAiSEEEIImyMJkBBC\
# CCFsjiRAQgghhLA5kgAJIYQQwuZIAiSEEEIImyMJkBBCCCFsjiRAQgghhLA5kgAJIYQQwuZIAiSE\
# EEIImyMJkBBCCCFsjiRAQgghhLA5kgAJIYQQwuZIAiSEEEIImyMJkBBCCCFsjiRAQgghhLA5kgAJ\
# IYQQwuZIAiSEEEIImyMJkBBCCC

# %%
v = jones.field_left_circular()
print("Jones vector for left circularly polarized light")
vis.draw_jones_animated(v,nframes=32)
# Out:
# Jones vector for left circularly polarized light
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img90d549b031324eaf83d499bd2f6d388c">
#   <div class="anim-controls">
#     <input id="_anim_slider90d549b031324eaf83d499bd2f6d388c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim90d549b031324eaf83d499bd2f6d388c.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim90d549b031324eaf83d499bd2f6d388c.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select90d549b031324eaf83d499bd2f6d388c" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_90d549b031324eaf83d499bd2f6d388c"
#              >
#       <label for="_anim_radio1_90d549b031324eaf83d499bd2f6d388c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_90d549b031324eaf83d499bd2f6d388c"
#              checked>
#       <label for="_anim_radio2_90d549b031324eaf83d499bd2f6d388c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_90d549b031324eaf83d499bd2f6d388c"
#              >
#       <label for="_anim_radio3_90d549b031324eaf83d499bd2f6d388c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img90d549b031324eaf83d499bd2f6d388c";
#     var slider_id = "_anim_slider90d549b031324eaf83d499bd2f6d388c";
#     var loop_select_id = "_anim_loop_select90d549b031324eaf83d499bd2f6d388c";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nOzdd1iT1xcH8G/CVhAVUBBR3BMBBere\
# e2vdCtZq1do6fuKo1j1bZ7HuugvuReveW8sQNypuRAUFkRVWcn5/XEVRlJXwBnM+z8MTSd733hNo\
# 4XDHuTIiIjDGGGOM6RC51AEwxhhjjOU1ToAYY4wxpnM4AWKMMcaYzuEEiDHGGGM6hxMgxhhjjOkc\
# ToAYY4wxpnM4AWKMMcaYzuEEiDHGGGM6hxMgxhhjjOkcToAYY4wxpnM4AWKMMcaYzuEEiDHGGGM6\
# hxMgxhhjjOkcToAYY4wxpnM4AWKMMcaYzuEEiDHGGGM6hxMgxhhjjOkcToAYY4wxpnM4AWKMMcaY\
# zuEEiDHGGGM6hxMgxhhjjOkcToAYY4wxpnM4AWKMMcaYzuEEiDHGGGM6hxMgxhhjjOkcToAYY4wx\
# pnM4AWKMMcaYzuEEiDHGGGM6hx
